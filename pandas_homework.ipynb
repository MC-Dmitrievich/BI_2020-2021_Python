# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
path = "https://raw.githubusercontent.com/Serfentum/bf_course/master/14.pandas/train.csv"
df = pd.read_csv(path)
df
# Out:
#     pos  reads_all  matches  mismatches  deletions  insertions       A      C  \
# 0   279       8045       32        7972         46           8  7911.0   54.0
# 1   280       8045     7995          48         19           9     NaN   16.0
# 2   281       8045     7983          50         16           5     NaN   24.0
# 3   282       8049     7510         505         33          65   105.0   11.0
# 4   283       8042     7786         155        115          62    46.0    NaN
# ..  ...        ...      ...         ...        ...         ...     ...    ...
# 58  337       8056     7542         471         58           7     NaN   63.0
# 59  338       8061     7967          62         29           5    17.0    NaN
# 60  339       8062     8002          48         14           3    14.0   14.0
# 61  340       8061     7918         146         16           4     NaN   75.0
# 62  341       8059     7869         192          2           4     NaN  134.0
#
# ...

# %%
# Problem 1
df2 = df[['pos', 'A', 'C', 'T', 'G']]
plt.rcParams['figure.figsize'] = [20, 8] 
df2.plot.bar(x='pos', stacked=True)
# Out:
# <AxesSubplot:xlabel='pos'>

# %%
# Problem 2 
matches_mean = df.matches.mean() 
df3 = df.loc[df.matches > matches_mean]
df4 = df3[['pos', 'reads_all', 'mismatches', 'deletions', 'insertions']]
df4.to_csv('train_part.csv')
df4
# Out:
#     pos  reads_all  mismatches  deletions  insertions
# 1   280       8045          48         19           9
# 2   281       8045          50         16           5
# 3   282       8049         505         33          65
# 4   283       8042         155        115          62
# 5   284       8048         104        864         241
# 17  296       8039        1883       1308          50
# 19  298       8047         769       1345          12
# 20  299       8043         728       1053          60
# 21  300       8049         862        468          64
# 22  301       8050        1395        516          51
# 25  304       8051        1492       1248          63
# 26  305       8048        1054       1641          36
# 32  311       8051        1479       1558          90
# 33  312       8051        1766       1556         159
# 34  313       8054        1337       1687          66
# 41  320       8052         584       1194          18
# ...

# %%
# EDA of wine_data
path_2 = "C:/Users/maxim/Downloads/archive (1)/winequality-red.csv"
wine = pd.read_csv(path_2)
wine.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
duplicate_rows_wf = wine[wine.duplicated()]
print("number of duplicate rows: ", duplicate_rows_wf.shape)
# Out:
# number of duplicate rows:  (240, 12)

# %%
wine.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
wf = wine.drop_duplicates()
wf.count()
# Out:
# fixed acidity           1359
# volatile acidity        1359
# citric acid             1359
# residual sugar          1359
# chlorides               1359
# free sulfur dioxide     1359
# total sulfur dioxide    1359
# density                 1359
# pH                      1359
# sulphates               1359
# alcohol                 1359
# quality                 1359
# dtype: int64

# %%
wf.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.hist(wf[['residual sugar']])
# Out:
# (array([832., 414.,  55.,  34.,   9.,   7.,   2.,   0.,   4.,   2.]),
#  array([ 0.9 ,  2.36,  3.82,  5.28,  6.74,  8.2 ,  9.66, 11.12, 12.58,
#         14.04, 15.5 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(data=wf)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=wf)
# Out:
# <AxesSubplot:>

# %%
quality_mean = wf.quality.mean() 
new_wf = wf.loc[wf.quality > quality_mean]
print("Number of good quality wine is", new_wf.shape[0])
# Out:
# Number of good quality wine is 719

# %%
plt.figure(figsize=(10,5))
corr = wf.corr()
sns.heatmap(corr,cmap="YlOrBr", annot=True)
# Out:
# <AxesSubplot:>

# %%
wf[['fixed acidity','citric acid','density']]
# Out:
#       fixed acidity  citric acid  density
# 0               7.4         0.00  0.99780
# 1               7.8         0.00  0.99680
# 2               7.8         0.04  0.99700
# 3              11.2         0.56  0.99800
# 5               7.4         0.00  0.99780
# ...             ...          ...      ...
# 1593            6.8         0.08  0.99651
# 1594            6.2         0.08  0.99490
# 1595            5.9         0.10  0.99512
# 1597            5.9         0.12  0.99547
# 1598            6.0         0.47  0.99549
#
# [1359 rows x 3 columns]

# %%
sns.heatmap(wf[['fixed acidity','citric acid','density']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data = wf, vars=['fixed acidity','citric acid','density'])
plt.show()
